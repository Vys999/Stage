# %%
#This small piece of code was used at the end of both neural net files, to store the obtained data
import glob
condition = "neighbour"       
save_name = f"{dataset_name}_binary_{condition}__{target_cue}vs{opp_cue}.npz" #File name
logreg_array = np.array(logreg_accuracy_list)
nn_array = np.array(nn_accuracy_list)
np.savez(
    save_name,
    logreg=logreg_accuracy_list,
    nn=nn_accuracy_list,
    time_period=time_period,
    dataset_name=dataset_name,
    cue_a=target_cue,
    cue_b=opp_cue,
    condition=condition,
    mean_logreg=np.mean(logreg_accuracy_list),
    mean_nn=np.mean(nn_accuracy_list)
)

print("Saved:", save_name)
